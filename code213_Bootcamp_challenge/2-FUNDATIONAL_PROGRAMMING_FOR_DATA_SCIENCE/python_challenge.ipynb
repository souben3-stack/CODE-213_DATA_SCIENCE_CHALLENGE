# %% [markdown]
# ### TASK 1

# %%
from datetime import datetime
#Ask the user for name and age
name = input("enter your name : ")
age = int(input(" enter your age "))
#get the current year
current_year= datetime.now().year
#calculate the yearc when the user turn 100
year_turn_100 = current_year +(100-age)
#print the result
print(f"Hello {name}, you will turn 100 years old in the year {year_turn_100}.")
# Out:
# Hello SIHEM, you will turn 100 years old in the year 2079.

# %% [markdown]
# ### TASK 2 GUESSING GAME

# %%
import random
#generate a random number between 1 to 9
number = random.randint(1, 10)
count = 0
while True:
    guess = int(input("guess a number between 1 to 10:"))
    count += 1
    if guess >number:
        print("you guess too high")
    elif guess<number:
        print("you guess too low")
    else:
        print(f"you guess right, it took you {count} guesses")
        break
# Out:
# you guess too low
# you guess too low
# you guess right, it took you 3 guesses

# %% [markdown]
# ### TASK 3

# %%
def get_element(list):
 first_element=list[0]
 last_element=list[-1]

 
 return{'Le premier element': first_element, 
       
    'Le dernier element': last_element
    }

list=[3, 4, 5, 6, 7]
get_element(list)
# Out:
# {'Le premier element': 3, 'Le dernier element': 7}

# %% [markdown]
# ### TASK 4

# %%
import string
import random

Ltr=string.ascii_letters
upper_Ltr=string.ascii_uppercase
lower_Ltr=string.ascii_lowercase
numbers=string.digits
punctuation=string.punctuation
lis = ["sihem", "password", "letters"]
password = random.choice(lis)

# %%
print(Ltr)
print(upper_Ltr)
print(lower_Ltr)
print(numbers)
print(punctuation)
print(password)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyz
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# sihem

# %%
def password(length, strength):
    if strength.lower =='weak':
        lis = ["sihem", "password", "letters"]
        password = random.choice(lis)
        return password
    else:
        all_chars = Ltr + punctuation + numbers + upper_Ltr + lower_Ltr
        password = ""
        for i in range(length):
            password += random.choice(all_chars)
        return password

# %%
password(length=12, strength='strong')
# Out:
# '+eGv3zPID/#4'
